# 45   GT86  2016  17500       Manual    14000   Petrol  260  36.2         2.0
# 46   GT86  2019  23997       Manual     4500   Petrol  145  33.2         2.0
# 47   GT86  2017  17102       Manual    21000   Petrol  260  36.2         2.0
# 48   GT86  2019  24995       Manual     2488   Petrol  145  33.2         2.0
# 49   GT86  2017  19995       Manual    26000   Petrol  145  36.2         2.0
# 50   GT86  2020  29769       Manual      999   Petrol  145  33.2         2.0
# 51   GT86  2019  25850       Manual     4442   Petrol  145  33.2         2.0
# 52   GT86  2014  13495       Manual    24667   Petrol  265  36.2         2.0
# 53   GT86  2017  18495    Semi-Auto    13930   Petrol  150  39.8         2.0
# 54   GT86  2020  25499       Manual      614   Petrol  145  33.2         2.0
# 55   GT86  2017  18621       Manual    18544   Petrol  150  36.2         2.0
# 56   GT86  2019  25121       Manual     7056   Petrol  145  33.2         2.0
# 57   GT86  2017  17500       Manual    11898   Petrol  145  36.2         2.0
# 58   GT86  2013  11599    Automatic    28335   Petrol  200  39.8         2.0
# 59   GT86  2017  17249       Manual    10089   Petrol  145  36.2         2.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6738 entries, 0 to 6737
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         6738 non-null   object
#  1   year          6738 non-null   int64
#  2   price         6738 non-null   int64
#  3   transmission  6738 non-null   object
#  4   mileage       6738 non-null   int64
#  5   fuelType      6738 non-null   object
#  6   tax           6738 non-null   int64
#  7   mpg           6738 non-null   float64
#  8   engineSize    6738 non-null   float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 473.9+ KB

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.describe()
# Out:
#               year         price        mileage          tax          mpg  \
# count  6738.000000   6738.000000    6738.000000  6738.000000  6738.000000
# mean   2016.748145  12522.391066   22857.413921    94.697240    63.042223
# std       2.204062   6345.017587   19125.464147    73.880776    15.836710
# min    1998.000000    850.000000       2.000000     0.000000     2.800000
# 25%    2016.000000   8290.000000    9446.000000     0.000000    55.400000
# 50%    2017.000000  10795.000000   18513.000000   135.000000    62.800000
# 75%    2018.000000  14995.000000   31063.750000   145.000000    69.000000
# max    2020.000000  59995.000000  174419.000000   565.000000   235.000000
#
#         engineSize
# count  6738.000000
# mean      1.471297
# std       0.436159
# min       0.000000
# 25%       1.000000
# 50%       1.500000
# 75%       1.800000
# max       4.500000

# %% [markdown]
# #Visualisai data

# %%
non_numeric_columns = data.select_dtypes(exclude=['float', 'int']).columns
print(non_numeric_columns)
numeric_data = data.select_dtypes(include=['float', 'int'])
plt.figure(figsize=(10, 9))
sns.heatmap(numeric_data.corr(), annot=True)
plt.show()
# Out:
# Index(['model', 'transmission', 'fuelType'], dtype='object')

# %% [markdown]
# #jumlah mobil berdasarkan model

# %%
models = data.groupby('model').count()[['tax']].sort_values(by='tax',ascending=True).reset_index()
models = models.rename(columns={'tax':'numberOfCars'})

# %%
fig = plt.figure(figsize=(15, 8))
fig = plt.figure(figsize=(15, 5))
fig = plt.figure(figsize=(15, 10))
fig = plt.figure(figsize=(15, 10))  
sns.barplot(x=models['model'], y=models['numberOfCars'], color='red')
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# #Size Egine

# %%
engine = data.groupby('engineSize').count()[['tax']].sort_values(by='tax').reset_index()
engine = engine.rename(columns={'tax':'count'})

# %%
plt.figure(figsize=(15,5))
sns.barplot(x=engine['engineSize'], y=engine['count'],color='blue')
# Out:
# <Axes: xlabel='engineSize', ylabel='count'>

# %% [markdown]
# #Distribusi Mileage

# %%
plt.figure(figsize=(15,5))
sns.displot(data['mileage'])

# %% [markdown]
# #Clustering harga

# %%
plt.figure(figsize=(15,5))
sns.displot(data['price'])

# %% [markdown]
# #Seleksi Fiture
